# %%
import json

fd = open("Record.json",'r')
record = fd.read()
fd.close()
RECORD = json.loads(record)

# %%
RECORD
# Out:
# {'1001': {'Name': 'Pasta',
#   'Quantity': 30,
#   'Price': 10,
#   'Discount': '2%',
#   'MRP': 15},
#  '1002': {'Name': 'Tablet',
#   'Price': 800,
#   'Quantity': 100,
#   'Discount': '10%',
#   'MRP': 900},
#  '1003': {'Name': 'Drink',
#   'Price': 85,
#   'Quantity': 100,
#   'Discount': '15%',
#   'MRP': 100},
#  '1004': {'Name': 'Candy',
#   'Price': 5,
#   'Quantity': 1000,
#   'Discount': '0%',
#   'MRP': 10},
#  '1005': {'Name': 'Pen',
#   'Price': 20,
#   'Quantity': 100,
#   'Discount': '25%',
#   'MRP': 30},
#  '1006': {'Name': 'Phone',
#   'Price': 50000,
#   'Quantity': 10,
#   'Discount': '20%',
#   'MRP': 60000},
#  '1007': {'Name': 'Mic',
#   'Price': 1500,
#   'Quantity': 0,
#   'Discount': '10%',
#   'MRP': 1700},
#  '1008': {'Name': 'Case',
#   'Price': 599,
#   'Quantity': 5,
#   'Discount': '7%',
#   'MRP': 700},
#  '1009': {'Name': 'Keyboard',
#   'Price': 1999,
#   'Quantity': 10,
#   'Discount': '17%',
#   'MRP': 2200},
#  '1010': {'Name': 'Book',
# ...

# %% [markdown]
# # Remove product from RECORD

# %%
id = int(input("Enter the Product Id : "))
del RECORD[str(id)]
# Out:
# Enter the Product Id : 1029

# %%
RECORD
# Out:
# {'1001': {'Name': 'Pasta',
#   'Quantity': 30,
#   'Price': 10,
#   'Discount': '2%',
#   'MRP': 15},
#  '1002': {'Name': 'Tablet',
#   'Price': 800,
#   'Quantity': 100,
#   'Discount': '10%',
#   'MRP': 900},
#  '1003': {'Name': 'Drink',
#   'Price': 85,
#   'Quantity': 100,
#   'Discount': '15%',
#   'MRP': 100},
#  '1004': {'Name': 'Candy',
#   'Price': 5,
#   'Quantity': 1000,
#   'Discount': '0%',
#   'MRP': 10},
#  '1005': {'Name': 'Pen',
#   'Price': 20,
#   'Quantity': 100,
#   'Discount': '25%',
#   'MRP': 30},
#  '1006': {'Name': 'Phone',
#   'Price': 50000,
#   'Quantity': 10,
#   'Discount': '20%',
#   'MRP': 60000},
#  '1007': {'Name': 'Mic',
#   'Price': 1500,
#   'Quantity': 0,
#   'Discount': '10%',
#   'MRP': 1700},
#  '1008': {'Name': 'Case',
#   'Price': 599,
#   'Quantity': 5,
#   'Discount': '7%',
#   'MRP': 700},
#  '1009': {'Name': 'Keyboard',
#   'Price': 1999,
#   'Quantity': 10,
#   'Discount': '17%',
#   'MRP': 2200},
#  '1010': {'Name': 'Book',
# ...
